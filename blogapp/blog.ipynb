# %%
from blogs.models import Post
from users.models import User
user = User.objects.get(id=7)

for i  in range(300):
    p = Post(user=user, title="django:[%03d]" % i, content='내용없음')
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from blogs.models import Post
#       2 from users.models import User
#       3 user = User.objects.get(id=7)
#
# File c:\source\djangosource\blogapp\blogs\models.py:2
#       1 from django.db import models
# ----> 2 from users.models import User
#       3 from taggit.managers import TaggableManager
#       6 # 번호(자동생성), user, 제목(title), 내용(content), image(option), 작성날짜(created_at), 수정날짜(modified_at)
#
# File c:\source\djangosource\blogapp\users\models.py:2
#       1 from django.db import models
# ----> 2 from django.contrib.auth.models import (
#       3     User,
#       4     AbstractUser,
#       5     PermissionsMixin,
#       6     BaseUserManager,
#       7 )
#       8 from django.contrib.auth.base_user import AbstractBaseUser
#      10 # AbstractBaseUser : password, last_login 필드만 가지고 있음
# ...
